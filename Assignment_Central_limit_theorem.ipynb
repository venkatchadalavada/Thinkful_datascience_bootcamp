# %%
# Initialize environment

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from numpy.random import randint
from numpy import mean
from scipy import stats
from numpy.random import seed

# %%
# for normal distribution
results = []
for num_trials in range(1,1000):
    trials = np.random.normal(2, 10, num_trials)
    mean_of_trials = trials.mean()
    results.append(mean_of_trials)
	
df = pd.DataFrame({ 'trials' : results})


df.plot()

# %%
means = [mean(randint(2, 10, 60)) for _ in range(1000)]


plt.hist(means)
plt.show()

print(stats.describe(means))
# Out:
# DescribeResult(nobs=1000, minmax=(4.533333333333333, 6.65), mean=5.499316666666666, variance=0.08649797547547547, skewness=-0.009867856520020393, kurtosis=0.23509339631978365)

# %%
# for normal distribution
results = []
for num_trials in range(1,1000):
    trials = np.random.gamma(2, 10, num_trials)
    mean_of_trials = trials.mean()
    results.append(mean_of_trials)
	
df = pd.DataFrame({ 'trials' : results})


df.plot()

# %%
means = [mean(randint(2, 10, 60)) for _ in range(1000)]


plt.hist(means)
plt.show()

print(stats.describe(means))
# Out:
# DescribeResult(nobs=1000, minmax=(4.383333333333334, 6.466666666666667), mean=5.512683333333333, variance=0.09346231759537316, skewness=-0.07057392108931396, kurtosis=-0.13444011680869794)
